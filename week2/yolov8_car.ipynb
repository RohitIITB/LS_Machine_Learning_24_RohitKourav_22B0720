# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.2/800.2 kB 16.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Yolo Learning/data
# Out:
# /content/drive/MyDrive/Yolo Learning/data

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=90 imgsz=352 plots=True
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image
Image(filename='runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train/results.png', width=600)

# %%
Image(filename='runs/detect/train/train_batch0.jpg', width=600)

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,131,776 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/drive/MyDrive/Yolo Learning/data/valid/labels.cache... 160 images, 1 backgrounds, 0 corrupt: 100% 160/160 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:08<00:00,  1.22it/s]
#                    all        160       1055      0.762      0.724      0.746      0.556
#                   boot         35         39      0.769       0.59      0.632      0.539
#                    car        142        145       0.91      0.966      0.949      0.909
#                   door         50         52      0.891      0.788      0.942       0.65
#           front_bumper         30         30      0.627      0.433      0.524      0.372
#            front_grill         49         51      0.649      0.652      0.665      0.557
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf= 0.25 source=test/images epochs=25 plots=True
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,131,776 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/22 /content/drive/MyDrive/Yolo Learning/data/test/images/Cars212_png.rf.c31b66dbfb5e4d5bc2e10f4b331f03aa.jpg: 352x352 1 car, 1 front_grill, 1 headlamp, 1 license_plate, 11.6ms
# image 2/22 /content/drive/MyDrive/Yolo Learning/data/test/images/Cars260_png.rf.358fc27422dbe6062fced88e7e5b59cc.jpg: 352x352 2 cars, 1 license_plate, 8.6ms
# image 3/22 /content/drive/MyDrive/Yolo Learning/data/test/images/Cars295_png.rf.5452c67121f3be7c3e37148a9cc4936d.jpg: 352x352 4 cars, 1 front_grill, 2 license_plates, 8.5ms
# image 4/22 /content/drive/MyDrive/Yolo Learning/data/test/images/Cars304_png.rf.f31408152fe09e73a74c2949a65058a0.jpg: 352x352 1 car, 1 front_grill, 2 headlamps, 1 license_plate, 1 wheel, 8.6ms
# ...
